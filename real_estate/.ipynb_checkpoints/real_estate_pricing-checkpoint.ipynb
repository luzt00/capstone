# %%
import requests

# API endpoint for Realtor v3 list
url = "https://realty-in-us.p.rapidapi.com/properties/v3/list"

# Headers with your API key and host
headers = {
    "content-type": "application/json",
    "X-RapidAPI-Key": "33f7baa8aemshb3380eca00fc1c0p16a229jsn6f972fd9d47e",  # <-- Replace if needed
    "X-RapidAPI-Host": "realty-in-us.p.rapidapi.com"
}

# Request payload (search by ZIP code in Phoenix)
payload = {
    "limit": 20,
    "offset": 0,
    "postal_code": "85004",  # You can replace with any Phoenix ZIP
    "status": ["for_sale"],
    "sort": {
        "direction": "desc",
        "field": "list_date"
    }
}

# Make the POST request
response = requests.post(url, json=payload, headers=headers)

# Parse the response
if response.status_code == 200:
    data = response.json()
    listings = data.get("data", {}).get("home_search", {}).get("results", [])
    
    if not listings:
        print("No listings found. Try another ZIP or adjust filters.")
    else:
        for i, home in enumerate(listings, 1):
            address = home['location']['address'].get('line', 'N/A')
            city = home['location']['address'].get('city', 'N/A')
            zipcode = home['location']['address'].get('postal_code', 'N/A')
            price = home.get('list_price', 'N/A')
            lat = home['location']['address'].get('coordinate', {}).get('lat', 'N/A')
            lon = home['location']['address'].get('coordinate', {}).get('lon', 'N/A')
            baths = home.get('description', {}).get('baths', 'N/A')
            beds = home.get('description', {}).get('beds', 'N/A')
            lot_size = home.get('description', {}).get('lot_sqft', 'N/A')
            type_ = home.get('description', {}).get('type', 'N/A')
            url = home.get('href', 'N/A')
     
            
            # Print nicely
            print(f"{i}. {address}, {city} {zipcode}")
            print(f"   Price: ${price:,} | Beds: {beds} | Baths: {baths}")
            print(f"   Coordinates: ({lat}, {lon})")
            print(f"   URL: {url}")
            print("-" * 60)

else:
    print(f"Error {response.status_code}: {response.text}")
# Out:
# 1. 1700 S 1st St Lot 1, Phoenix 85004
#    Price: $275,000 | Beds: None | Baths: 0
#    Coordinates: (33.431198, -112.07296)
#    URL: https://www.realtor.com/realestateandhomes-detail/1700-S-1st-St-1_Phoenix_AZ_85004_M92311-69311
# ------------------------------------------------------------
# 2. 377 E Windsor Ave Unit 24, Phoenix 85004
#    Price: $750,000 | Beds: 2 | Baths: 3
#    Coordinates: (33.477791, -112.065941)
#    URL: https://www.realtor.com/realestateandhomes-detail/377-E-Windsor-Ave-Unit-24_Phoenix_AZ_85004_M92796-72545
# ------------------------------------------------------------
# 3. 361 E Palm Ln, Phoenix 85004
#    Price: $595,000 | Beds: 2 | Baths: 2
#    Coordinates: (33.468637, -112.066794)
#    URL: https://www.realtor.com/realestateandhomes-detail/361-E-Palm-Ln_Phoenix_AZ_85004_M15997-21339
# ------------------------------------------------------------
# 4. 310 S 4th St Unit 601, Phoenix 85004
#    Price: $538,900 | Beds: 2 | Baths: 3
#    Coordinates: (33.444553, -112.069165)
#    URL: https://www.realtor.com/realestateandhomes-detail/310-S-4th-St-Unit-601_Phoenix_AZ_85004_M29590-63450
# ------------------------------------------------------------
# 5. 312 E Windsor Ave Unit 6, Phoenix 85004
#    Price: $879,000 | Beds: 3 | Baths: 3
#    Coordinates: (33.478319, -112.068805)
#    URL: https://www.realtor.com/realestateandhomes-detail/312-E-Windsor-Ave_Phoenix_AZ_85004_M91486-39624
# ------------------------------------------------------------
# 6. 1130 N 2nd St Apt 306, Phoenix 85004
#    Price: $317,000 | Beds: 1 | Baths: 1
#    Coordinates: (33.461033, -112.071567)
#    URL: https://www.realtor.com/realestateandhomes-detail/1130-N-2nd-St-Apt-306_Phoenix_AZ_85004_M22785-05254
# ------------------------------------------------------------
# 7. 1014 S 2nd St, Phoenix 85004
#    Price: $545,000 | Beds: None | Baths: None
#    Coordinates: (33.437522, -112.071553)
#    URL: https://www.realtor.com/realestateandhomes-detail/1014-S-2nd-St_Phoenix_AZ_85004_M13474-42464
# ------------------------------------------------------------
# 8. 610 E Roosevelt St Unit 145, Phoenix 85004
#    Price: $1,000,000 | Beds: 1 | Baths: 2
#    Coordinates: (33.458861, -112.066287)
#    URL: https://www.realtor.com/realestateandhomes-detail/610-E-Roosevelt-St-Unit-145_Phoenix_AZ_85004_M11091-95332
# ------------------------------------------------------------
# 9. 1130 N 2nd St Apt 208, Phoenix 85004
#    Price: $454,000 | Beds: 2 | Baths: 2
#    Coordinates: (33.460956, -112.071565)
#    URL: https://www.realtor.com/realestateandhomes-detail/1130-N-2nd-St-Apt-208_Phoenix_AZ_85004_M22179-74695
# ------------------------------------------------------------
# 10. 325 E Coronado Rd Unit 8, Phoenix 85004
#    Price: $630,000 | Beds: 2 | Baths: 3
#    Coordinates: (33.467175, -112.068093)
#    URL: https://www.realtor.com/realestateandhomes-detail/325-E-Coronado-Rd-Unit-8_Phoenix_AZ_85004_M27880-80455
# ------------------------------------------------------------
# 11. 312 E Windsor Ave Unit 13, Phoenix 85004
#    Price: $929,900 | Beds: 3 | Baths: 3
#    Coordinates: (33.478287, -112.068619)
#    URL: https://www.realtor.com/realestateandhomes-detail/312-E-Windsor-Ave-13_Phoenix_AZ_85004_M94638-33161
# ------------------------------------------------------------
# 12. 2302 N Central Ave Unit 206, Phoenix 85004
#    Price: $425,000 | Beds: 2 | Baths: 2
#    Coordinates: (33.473375, -112.074125)
#    URL: https://www.realtor.com/realestateandhomes-detail/2302-N-Central-Ave-Unit-206_Phoenix_AZ_85004_M13208-86735
# ------------------------------------------------------------
# 13. 2302 N Central Ave Unit 311, Phoenix 85004
#    Price: $350,000 | Beds: 2 | Baths: 2
#    Coordinates: (33.473652, -112.074251)
#    URL: https://www.realtor.com/realestateandhomes-detail/2302-N-Central-Ave-Unit-311_Phoenix_AZ_85004_M19358-54362
# ------------------------------------------------------------
# 14. 310 S 4th St Unit 1601, Phoenix 85004
#    Price: $568,104 | Beds: 2 | Baths: 3
#    Coordinates: (33.444553, -112.069165)
#    URL: https://www.realtor.com/realestateandhomes-detail/310-S-4th-St-Unit-1601_Phoenix_AZ_85004_M13032-22678
# ------------------------------------------------------------
# 15. 1014 S 2nd St, Phoenix 85004
#    Price: $545,000 | Beds: 4 | Baths: 3
#    Coordinates: (33.437522, -112.071553)
#    URL: https://www.realtor.com/realestateandhomes-detail/1014-S-2nd-St_Phoenix_AZ_85004_M13474-42464
# ------------------------------------------------------------
# 16. 2201 N Central Ave Apt 3C, Phoenix 85004
#    Price: $385,000 | Beds: 2 | Baths: 1
#    Coordinates: (33.471653, -112.073128)
#    URL: https://www.realtor.com/realestateandhomes-detail/2201-N-Central-Ave-Apt-3C_Phoenix_AZ_85004_M11536-87993
# ------------------------------------------------------------
# 17. 424 S 2nd St Unit 306, Phoenix 85004
#    Price: $415,000 | Beds: 1 | Baths: 2
#    Coordinates: (33.443357, -112.071563)
#    URL: https://www.realtor.com/realestateandhomes-detail/424-S-2nd-St-Unit-306_Phoenix_AZ_85004_M21552-16252
# ------------------------------------------------------------
# 18. 319 E Coronado Rd Unit 1, Phoenix 85004
#    Price: $1,500,000 | Beds: None | Baths: None
#    Coordinates: (33.467362, -112.068403)
#    URL: https://www.realtor.com/realestateandhomes-detail/319-E-Coronado-Rd-Unit-1_Phoenix_AZ_85004_M10835-88218
# ------------------------------------------------------------
# 19. 1755 S Central Ave Lot 15, Phoenix 85004
#    Price: $3,369,000 | Beds: None | Baths: 0
#    Coordinates: (33.429905, -112.073212)
#    URL: https://www.realtor.com/realestateandhomes-detail/1755-S-Central-Ave-15_Phoenix_AZ_85004_M99159-17380
# ------------------------------------------------------------
# 20. 1130 N 2nd St Apt 401, Phoenix 85004
#    Price: $459,999 | Beds: 2 | Baths: 2
#    Coordinates: (33.461164, -112.071804)
#    URL: https://www.realtor.com/realestateandhomes-detail/1130-N-2nd-St-Apt-401_Phoenix_AZ_85004_M20942-61946
# ------------------------------------------------------------
